# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print(123)
# Out:
# 123

# %%
print(1232.5)
# Out:
# 1232.5

# %%
print("Hello","World")
# Out:
# Hello World

# %%
print("Hello",123,True)
# Out:
# Hello 123 True

# %%
print("Hello","World",123,sep="#")
# Out:
# Hello#World#123

# %%
print("Hello",end = "\n")
print("World!",end = "\n")
print(123)
# Out:
# Hello
# World!
# 123

# %%
###Data Types
Basic Data types (integer,float,value,Boolean,String,Complex)
container data types(List,Tuples,Sets,Dictionary)
Unser Define types(Class)

# %%
print(5+6j)
# Out:
# (5+6j)

# %%
# list
print([1,2,"h"])
# Out:
# [1, 2, 'h']

# %%
# Tuple
print((544,'dfgdf',True))
# Out:
# (544, 'dfgdf', True)

# %%
#Sets
print({"type",2324,False})
# Out:
# {False, 2324, 'type'}

# %%
#Dictionary
print({"Name":"Abdullah","Roll no":123})
# Out:
# {'Name': 'Abdullah', 'Roll no': 123}

# %%
#String
print('My name is Abdullah')
print("My name is"+" "+"Abdullah")
print('''Abdullah''')
# Out:
# My name is Abdullah
# My name is Abdullah
# Abdullah

# %%
type(123)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
type([1,2,3,5])
# Out:
# list

# %%
print(3567488939828448748748748728748474767487477)
# Out:
# 3567488939828448748748748728748474767487477

# %%
print(1e309)
# Out:
# inf

# %%
print(1.7e309)
# Out:
# inf

# %%
print(123+3.56)
# Out:
# 126.56

# %%
# Print Function
print("Hello")
# Out:
# Hello

# %%
name=5
print(name)
name=6
print(name)
# Out:
# 5
# 6

# %%
n1=3
n2=5
print(n1)
print(n2)
# Out:
# 3
# 5

# %%
n1=5;n2=6;n3=9
print(n1,n2,n3)
# Out:
# 5 6 9

# %%
a,b,c=2,3,4
print(a,b,c)
# Out:
# 2 3 4

# %%
a=10
b=10
c=10
print(a,b,c)

a=b=c=11
print(a,b,c)
# Out:
# 10 10 10
# 11 11 11

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
_="Name"
print(_)
# Out:
# Name

# %%
2="Name"
print=2
# Out:
#   Cell In[9], line 1
#     2="Name"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
Abdul_='Abdul'
print(Abdul_)
# Out:
# Abdul

# %%
2string=23
print(2string)
# Out:
#   Cell In[38], line 1
#     2string=23
#     ^
# SyntaxError: invalid decimal literal

# %%
input()
# Out:
#  56
# '56'

# %%
name=float(input("Name: "))

print(name)
print(type(name))
# Out:
# Name:  34.6
# 34.6
# <class 'float'>

# %%
num1=int(input("Enter Number 1. "))
num2=int(input("Enter Number 2. "))

result=num1+num2

print(result)
# Out:
# Enter Number 1.  45
# Enter Number 2.  45
# 90
